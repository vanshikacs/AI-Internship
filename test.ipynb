# %%
x = [1, 2, 3, 4, 5]
y = [7, 14, 15, 18, 19]

# %%
import pandas as pd

# %%
data = pd.read_csv("Lab_winequality-red.csv")
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = pd.read_csv("Lab_winequality-red.csv")
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:1922, in TextFileReader._make_engine(self, f, engine)
#    1919     raise ValueError(msg)
#    1921 try:
# -> 1922     return mapping[engine](f, **self.options)
#    1923 except Exception:
#    1924     if self.handles is not None:
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:95, in CParserWrapper.__init__(self, src, **kwds)
#      92 if kwds["dtype_backend"] == "pyarrow":
#      93     # Fail here loudly instead of in cython after reading
#      94     import_optional_dependency("pyarrow")
# ---> 95 self._reader = parsers.TextReader(src, **kwds)
#      97 self.unnamed_cols = self._reader.unnamed_cols
#      99 passed_names = self.names is None
#
# File pandas/_libs/parsers.pyx:575, in pandas._libs.parsers.TextReader.__cinit__()
# --> 575 'Could not get source, probably due dynamically evaluated source code.'
#
# EmptyDataError: No columns to parse from file

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

model = LinearRegression()

x = np.array(x).reshape(-1,1)
y = np.array(y)

model.fit(x,y)
# Out:
# LinearRegression()

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from tensorflow.keras.models import Sequential
#       2 from tensorflow.keras.layers import Dense, Activation
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
pip install tensorflow
# Out:
# Collecting tensorflow
#   Using cached tensorflow-2.21.0-cp311-cp311-win_amd64.whl.metadata (4.5 kB)
# Collecting absl-py>=1.0.0 (from tensorflow)
#   Using cached absl_py-2.5.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=25.9.23 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl.metadata (5.3 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (26.2)
# Collecting protobuf<8.0.0,>=6.31.1 (from tensorflow)
#   Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl.metadata (595 bytes)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (2.34.2)
# Requirement already satisfied: setuptools in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Using cached termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (4.16.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Using cached wrapt-2.2.2-cp311-cp311-win_amd64.whl.metadata (7.6 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.82.0-cp311-cp311-win_amd64.whl.metadata (3.8 kB)
# Collecting keras>=3.12.0 (from tensorflow)
#   Using cached keras-3.15.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from tensorflow) (2.4.6)
# Collecting h5py<3.15.0,>=3.11.0 (from tensorflow)
#   Using cached h5py-3.14.0-cp311-cp311-win_amd64.whl.metadata (2.7 kB)
# Collecting ml_dtypes<1.0.0,>=0.5.1 (from tensorflow)
#   Using cached ml_dtypes-0.5.4-cp311-cp311-win_amd64.whl.metadata (9.2 kB)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.47.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting rich (from keras>=3.12.0->tensorflow)
#   Using cached rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting namex (from keras>=3.12.0->tensorflow)
#   Using cached namex-0.1.0-py3-none-any.whl.metadata (322 bytes)
# Collecting optree (from keras>=3.12.0->tensorflow)
#   Using cached optree-0.19.1-cp311-cp311-win_amd64.whl.metadata (32 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Collecting markdown-it-py>=2.2.0 (from rich->keras>=3.12.0->tensorflow)
#   Using cached markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from rich->keras>=3.12.0->tensorflow) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich->keras>=3.12.0->tensorflow)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Using cached tensorflow-2.21.0-cp311-cp311-win_amd64.whl (350.8 MB)
# Using cached absl_py-2.5.0-py3-none-any.whl (137 kB)
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.82.0-cp311-cp311-win_amd64.whl (5.0 MB)
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.0 MB ? eta -:--:--
#    - -------------------------------------- 0.2/5.0 MB 6.3 MB/s eta 0:00:01
#    ------- -------------------------------- 1.0/5.0 MB 12.2 MB/s eta 0:00:01
#    -------------- ------------------------- 1.8/5.0 MB 14.1 MB/s eta 0:00:01
#    -------------------- ------------------- 2.6/5.0 MB 16.7 MB/s eta 0:00:01
#    ------------------------- -------------- 3.2/5.0 MB 14.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 4.3/5.0 MB 15.3 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  5.0/5.0 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------- 5.0/5.0 MB 12.8 MB/s eta 0:00:00
# Using cached h5py-3.14.0-cp311-cp311-win_amd64.whl (2.9 MB)
# Using cached keras-3.15.0-py3-none-any.whl (1.7 MB)
# Using cached libclang-18.1.1-py2.py3-none-win_amd64.whl (26.4 MB)
# Using cached ml_dtypes-0.5.4-cp311-cp311-win_amd64.whl (210 kB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached protobuf-7.35.1-cp310-abi3-win_amd64.whl (439 kB)
# Using cached termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Using cached wrapt-2.2.2-cp311-cp311-win_amd64.whl (80 kB)
# Using cached wheel-0.47.0-py3-none-any.whl (32 kB)
# Using cached namex-0.1.0-py3-none-any.whl (5.9 kB)
# Using cached optree-0.19.1-cp311-cp311-win_amd64.whl (337 kB)
# Using cached rich-15.0.0-py3-none-any.whl (310 kB)
# Using cached markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Installing collected packages: namex, libclang, flatbuffers, wrapt, wheel, termcolor, protobuf, optree, opt_einsum, ml_dtypes, mdurl, h5py, grpcio, google_pasta, gast, absl-py, markdown-it-py, astunparse, rich, keras, tensorflow
# Successfully installed absl-py-2.5.0 astunparse-1.6.3 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.82.0 h5py-3.14.0 keras-3.15.0 libclang-18.1.1 markdown-it-py-4.2.0 mdurl-0.1.2 ml_dtypes-0.5.4 namex-0.1.0 opt_einsum-3.4.0 optree-0.19.1 protobuf-7.35.1 rich-15.0.0 tensorflow-2.21.0 termcolor-3.3.0 wheel-0.47.0 wrapt-2.2.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.21.0

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation

# %%
model = Sequential()

# %%
model.add(Dense(64, input_shape=(10,), activation="relu"))
# Out:
# c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\keras\src\layers\core\dense.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.add(Dense(1, activation="sigmoid"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 769 (3.00 KB)
#  Trainable params: 769 (3.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss="binary_crossentropy",
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
print(model)
# Out:
# <Sequential name=sequential, built=True>

# %%
model.fit(X, y, epochs=10)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 model.fit(X, y, epochs=10)
#
# NameError: name 'X' is not defined
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
joblib.dump(model, "house_rent_prediction.pkl")
joblib.dump(encoder, "encoder.pkl")
joblib.dump(scaler, "scaler.pkl")

print("Saved successfully!")
# Out:
# Saved successfully!
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
prediction = model.predict([[6]])
print(prediction)
# Out:
# [23.]

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [2.8]
# 6.199999999999999

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

print("Predicted:", y_pred)
print("Actual:", y_test)
# Out:
# Predicted: [10.85714286 22.        ]
# Actual: [14 19]

# %%
print(model.score(x_test, y_test))
# Out:
# -0.510204081632653

# %%
import pandas as pd

data = pd.read_csv("bp.csv")
print(data.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 3
#       1 import pandas as pd
#       2
# ----> 3 data = pd.read_csv("bp.csv")
#       4 print(data.head())
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'bp.csv'

# %%
import pandas as pd

data = pd.read_csv("bp.csv")
print(data.head())
# Out:
#    Subject_ID  Age  Weight  Diastolic BP (mm Hg)  Systolic BP (mm Hg)
# 0           1   22      55                    78                  118
# 1           2   25      60                    80                  122
# 2           3   28      65                    82                  126
# 3           4   30      70                    84                  130
# 4           5   35      75                    86                  135

# %%
# Define target (y)
y = data["Systolic BP (mm Hg)"]

# Define features (X)
x = data.drop(columns=["Systolic BP (mm Hg)", "Subject_ID"])

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)

print("Predicted Values:", y_pred)
print("Actual Values:", y_test.values)

print("R² Score:", model.score(x_test, y_test))
# Out:
# Predicted Values: [155.00626118 122.06261181]
# Actual Values: [155 122]
# R² Score: 0.9999927282998458

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("bp.csv")

# Display the first 5 rows
print(data.head())

# Define target (y)
y = data["Systolic BP (mm Hg)"]

# Define features (x)
x = data.drop(columns=["Systolic BP (mm Hg)", "Subject_ID"])

# Check shapes
print("X shape:", x.shape)
print("Y shape:", y.shape)

# Split into training and testing sets
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(
    x,
    y,
    test_size=0.2,
    random_state=42
)

print("Training set:", x_train.shape)
print("Testing set:", x_test.shape)
# Out:
#    Subject_ID  Age  Weight  Diastolic BP (mm Hg)  Systolic BP (mm Hg)
# 0           1   22      55                    78                  118
# 1           2   25      60                    80                  122
# 2           3   28      65                    82                  126
# 3           4   30      70                    84                  130
# 4           5   35      75                    86                  135
# X shape: (10, 3)
# Y shape: (10,)
# Training set: (8, 3)
# Testing set: (2, 3)

# %%
import pandas as pd
data = pd.read_csv('bp.csv')
data.head()
y = data['Systolic BP (mm Hg)']
x = data.drop(['Systolic BP (mm Hg)','Subject_ID'], axis=1)
print(x.shape, y.shape)
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Out:
# (10, 3) (10,)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

print(y_pred)
# Out:
# [155.00626118 122.06261181]

# %%
from sklearn.metrics import mean_absolute_error

mae = mean_absolute_error(y_test, y_pred)

print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Absolute Error (MAE): 0.034436493738809304

# %%
import category_encoders as ce

encoder = ce.LeaveOneOutEncoder()

X = encoder.fit_transform(x, y)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import category_encoders as ce
#       2
#       3 encoder = ce.LeaveOneOutEncoder()
#       4
#
# ModuleNotFoundError: No module named 'category_encoders'

# %%
pip install category_encoders
# Out:
# Collecting category_encoders
#   Downloading category_encoders-2.9.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from category_encoders) (2.4.6)
# Requirement already satisfied: pandas>=1.0.5 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from category_encoders) (3.0.3)
# Collecting patsy>=0.5.1 (from category_encoders)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: scikit-learn>=1.6.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from category_encoders) (1.9.0)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from category_encoders) (1.17.1)
# Collecting statsmodels>=0.9.0 (from category_encoders)
#   Downloading statsmodels-0.14.6-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from pandas>=1.0.5->category_encoders) (2026.2)
# Requirement already satisfied: joblib>=1.4.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (2.23.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from scikit-learn>=1.6.0->category_encoders) (3.6.0)
# Requirement already satisfied: packaging>=21.3 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from statsmodels>=0.9.0->category_encoders) (26.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\desktop\internship_ai\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.0.5->category_encoders) (1.17.0)
# Downloading category_encoders-2.9.0-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/85.9 kB ? eta -:--:--
#    ---- ----------------------------------- 10.2/85.9 kB ? eta -:--:--
#    -------------- ------------------------- 30.7/85.9 kB 163.8 kB/s eta 0:00:01
#    ------------------- -------------------- 41.0/85.9 kB 196.9 kB/s eta 0:00:01
#    --------------------------------- ------ 71.7/85.9 kB 302.7 kB/s eta 0:00:01
#    ---------------------------------------- 85.9/85.9 kB 284.3 kB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ---------------------------------------- 0.0/233.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/233.3 kB ? eta -:--:--
#    - -------------------------------------- 10.2/233.3 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/233.3 kB 279.3 kB/s eta 0:00:01
#    ------ -------------------------------- 41.0/233.3 kB 279.3 kB/s eta 0:00:01
#    ------------------ ------------------- 112.6/233.3 kB 467.6 kB/s eta 0:00:01
#    ----------------------- -------------- 143.4/233.3 kB 532.5 kB/s eta 0:00:01
#    ---------------------------- --------- 174.1/233.3 kB 615.9 kB/s eta 0:00:01
#    ---------------------------- --------- 174.1/233.3 kB 615.9 kB/s eta 0:00:01
#    --------------------------------- ---- 204.8/233.3 kB 497.6 kB/s eta 0:00:01
#    ------------------------------------ - 225.3/233.3 kB 491.0 kB/s eta 0:00:01
#    -------------------------------------- 233.3/233.3 kB 492.4 kB/s eta 0:00:00
# Downloading statsmodels-0.14.6-cp311-cp311-win_amd64.whl (9.6 MB)
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.6 MB 435.7 kB/s eta 0:00:22
#    ---------------------------------------- 0.1/9.6 MB 440.4 kB/s eta 0:00:22
#     --------------------------------------- 0.1/9.6 MB 950.9 kB/s eta 0:00:10
#     --------------------------------------- 0.2/9.6 MB 1.0 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/9.6 MB 1.3 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/9.6 MB 1.5 MB/s eta 0:00:06
#    - -------------------------------------- 0.4/9.6 MB 1.5 MB/s eta 0:00:06
#    -- ------------------------------------- 0.5/9.6 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.6 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.6/9.6 MB 1.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.6 MB 1.3 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/9.6 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.7/9.6 MB 1.2 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.6 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.9/9.6 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.6 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.6 MB 1.4 MB/s eta 0:00:07
#    ---- ----------------------------------- 1.1/9.6 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.2/9.6 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.2/9.6 MB 1.4 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.6 MB 1.4 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.4/9.6 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.5/9.6 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.6 MB 1.5 MB/s eta 0:00:06
#    ------- -------------------------------- 1.8/9.6 MB 1.6 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.6 MB 1.7 MB/s eta 0:00:05
#    -------- ------------------------------- 2.1/9.6 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.2/9.6 MB 1.7 MB/s eta 0:00:05
#    --------- ------------------------------ 2.2/9.6 MB 1.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 2.5/9.6 MB 1.8 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.7/9.6 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.8/9.6 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 2.9/9.6 MB 1.9 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.6 MB 2.0 MB/s eta 0:00:04
#    ------------- -------------------------- 3.3/9.6 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.6 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.6 MB 2.0 MB/s eta 0:00:04
#    -------------- ------------------------- 3.5/9.6 MB 2.0 MB/s eta 0:00:04
#    ---------------- ----------------------- 3.8/9.6 MB 2.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.6 MB 2.3 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.6 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.6 MB 2.2 MB/s eta 0:00:03
#    ------------------- -------------------- 4.7/9.6 MB 2.4 MB/s eta 0:00:03
#    -------------------- ------------------- 4.8/9.6 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.6 MB 2.4 MB/s eta 0:00:02
#    --------------------- ------------------ 5.1/9.6 MB 2.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.6 MB 2.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 5.4/9.6 MB 2.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.6/9.6 MB 2.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 5.6/9.6 MB 2.4 MB/s eta 0:00:02
#    ------------------------- -------------- 6.2/9.6 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 2.6 MB/s eta 0:00:02
#    -------------------------- ------------- 6.3/9.6 MB 2.6 MB/s eta 0:00:02
#    --------------------------- ------------ 6.5/9.6 MB 2.5 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.9/9.6 MB 2.7 MB/s eta 0:00:02
#    ---------------------------- ----------- 6.9/9.6 MB 2.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.0/9.6 MB 2.6 MB/s eta 0:00:02
#    ----------------------------- ---------- 7.1/9.6 MB 2.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 7.2/9.6 MB 2.6 MB/s eta 0:00:01
#    ------------------------------ --------- 7.2/9.6 MB 2.5 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.6 MB 2.7 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.6 MB 2.7 MB/s eta 0:00:01
#    -------------------------------- ------- 7.8/9.6 MB 2.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.2/9.6 MB 2.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 8.3/9.6 MB 2.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.6 MB 2.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------  9.6/9.6 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.6/9.6 MB 2.9 MB/s eta 0:00:00
# Installing collected packages: patsy, statsmodels, category_encoders
# Successfully installed category_encoders-2.9.0 patsy-1.0.2 statsmodels-0.14.6
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

data = pd.read_csv("House_Rent_Dataset.csv")

print(data.head())
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
import category_encoders as ce

encoder = ce.LeaveOneOutEncoder()

x = encoder.fit_transform(x, y)

print(x.head())
# Out:
# Warning: No categorical columns found. Calling 'transform' will only return input data.
#    Age  Weight  Diastolic BP (mm Hg)
# 0   22      55                    78
# 1   25      60                    80
# 2   28      65                    82
# 3   30      70                    84
# 4   35      75                    86

# %%
new_house = pd.DataFrame({
    'BHK': [2],
    'Size': [1200],
    'Area Type': ['Super Area'],
    'City': ['Delhi'],
    'Furnishing Status': ['Semi-Furnished'],
    'Tenant Preferred': ['Family'],
    'Bathroom': [2],
    'Point of Contact': ['Contact Owner']
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_house = pd.DataFrame({
#       2     'BHK': [2],
#       3     'Size': [1200],
#       4     'Area Type': ['Super Area'],
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
new_house = pd.DataFrame({
    'BHK': [2],
    'Size': [1200],
    'Area Type': ['Super Area'],
    'City': ['Delhi'],
    'Furnishing Status': ['Semi-Furnished'],
    'Tenant Preferred': ['Family'],
    'Bathroom': [2],
    'Point of Contact': ['Contact Owner']
})

# %%
new_encoded = encoder.transform(new_house)

new_scaled = scaler.transform(new_encoded)

prediction = model.predict(new_scaled)

print("Predicted Rent:", prediction[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 new_encoded = encoder.transform(new_house)
#       2
#       3 new_scaled = scaler.transform(new_encoded)
#       4
#
# NameError: name 'encoder' is not defined

# %%
import pandas as pd

import category_encoders as ce

from sklearn.model_selection import train_test_split

from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression

# %%
new_encoded = encoder.transform(new_house)

new_scaled = scaler.transform(new_encoded)

prediction = model.predict(new_scaled)

print("Predicted Rent:", prediction[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 new_encoded = encoder.transform(new_house)
#       2
#       3 new_scaled = scaler.transform(new_encoded)
#       4
#
# NameError: name 'encoder' is not defined

# %%
model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 model.fit(x_train, y_train)
#
# NameError: name 'model' is not defined

# %%
import pandas as pd
import category_encoders as ce
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
import joblib

# %%
data = pd.read_csv("House_Rent_Dataset.csv")

# %%
y = data["Rent"]
x = data.drop(columns=["Rent", "Posted On", "Floor", "Area Locality"])

# %%
encoder = ce.LeaveOneOutEncoder()
x = encoder.fit_transform(x, y)

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
import joblib

joblib.dump(model, "house_rent_prediction.pkl")
joblib.dump(encoder, "encoder.pkl")
joblib.dump(scaler, "scaler.pkl")

print("Files saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 3
#       1 import joblib
#       2
# ----> 3 joblib.dump(model, "house_rent_prediction.pkl")
#       4 joblib.dump(encoder, "encoder.pkl")
#       5 joblib.dump(scaler, "scaler.pkl")
#       6
#
# NameError: name 'model' is not defined

# %%
import category_encoders as ce

encoder = ce.LeaveOneOutEncoder()

x = encoder.fit_transform(x, y)

# %%
new_house = pd.DataFrame({
    'BHK': [2],
    'Size': [1200],
    'Area Type': ['Super Area'],
    'City': ['Delhi'],
    'Furnishing Status': ['Semi-Furnished'],
    'Tenant Preferred': ['Family'],
    'Bathroom': [2],
    'Point of Contact': ['Contact Owner']
})

new_encoded = encoder.transform(new_house)
new_scaled = scaler.transform(new_encoded)
prediction = model.predict(new_scaled)
print("Predicted Rent:", prediction[0])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 13
#       9     'Point of Contact': ['Contact Owner']
#      10 })
#      11
#      12 new_encoded = encoder.transform(new_house)
# ---> 13 new_scaled = scaler.transform(new_encoded)
#      14 prediction = model.predict(new_scaled)
#      15 print("Predicted Rent:", prediction[0])
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\preprocessing\_data.py:1132, in StandardScaler.transform(self, X, copy)
#    1130 else:
#    1131     if self.with_mean:
# -> 1132         X -= xp.astype(self.mean_, X.dtype)
#    1133     if self.with_std:
#    1134         X /= xp.astype(self.scale_, X.dtype)
#
# AttributeError: 'StandardScaler' object has no attribute 'mean_'

# %%
data = pd.read_csv("House_Rent_Dataset.csv")

print(data.head())
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
y = data["Rent"]

x = data.drop(columns=["Rent", "Posted On", "Floor", "Area Locality"])

# %%
x_train, x_test, y_train, y_test = train_test_split(

x, y, test_size=0.2, random_state=42

)

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)

x_test = scaler.transform(x_test)

model = LinearRegression()

model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       5 )
#       6
#       7 scaler = StandardScaler()
#       8
# ----> 9 x_train = scaler.fit_transform(x_train)
#      10
#      11 x_test = scaler.transform(x_test)
#      12
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\utils\_set_output.py:319, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     317 @wraps(f)
#     318 def wrapped(self, X, *args, **kwargs):
# --> 319     data_to_wrap = f(self, X, *args, **kwargs)
#     320     if isinstance(data_to_wrap, tuple):
#     321         # only wrap the first output for cross decomposition
#     322         return_tuple = (
#     323             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     324             *data_to_wrap[1:],
#     325         )
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\base.py:969, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     954         warnings.warn(
#     955             (
#     956                 f"This object ({self.__class__.__name__}) has a `transform`"
#    (...)    964             UserWarning,
#     965         )
#     967 if y is None:
#     968     # fit method of arity 1 (unsupervised transformation)
# --> 969     return self.fit(X, **fit_params).transform(X)
#     970 else:
#     971     # fit method of arity 2 (supervised transformation)
#     972     return self.fit(X, y, **fit_params).transform(X)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\preprocessing\_data.py:928, in StandardScaler.fit(self, X, y, sample_weight)
#     926 # Reset internal state before fitting
#     927 self._reset()
# --> 928 return self.partial_fit(X, y, sample_weight)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\base.py:1403, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1393     estimator._validate_params()
#    1395 with (
#    1396     config_context(
#    1397         skip_parameter_validation=(
#    (...)   1401     callback_management_context(estimator),
#    1402 ):
# -> 1403     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\preprocessing\_data.py:965, in StandardScaler.partial_fit(self, X, y, sample_weight)
#     963 xp, _, X_device = get_namespace_and_device(X)
#     964 first_call = not hasattr(self, "n_samples_seen_")
# --> 965 X = validate_data(
#     966     self,
#     967     X,
#     968     accept_sparse=("csr", "csc"),
#     969     dtype=supported_float_dtypes(xp, X_device),
#     970     ensure_all_finite="allow-nan",
#     971     reset=first_call,
#     972 )
#     973 n_features = X.shape[1]
#     975 callback_ctx = self._init_callback_context()
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\utils\validation.py:1035, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1033         array = xp.astype(array, dtype, copy=False)
#    1034     else:
# -> 1035         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#    1036 except ComplexWarning as complex_warning:
#    1037     raise ValueError(
#    1038         "Complex data not supported\n{}\n".format(array)
#    1039     ) from complex_warning
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\sklearn\utils\_array_api.py:976, in _asarray_with_order(array, dtype, order, copy, xp, device)
#     974     array = numpy.array(array, order=order, dtype=dtype)
#     975 else:
# --> 976     array = numpy.asarray(array, order=order, dtype=dtype)
#     978 # At this point array is a NumPy ndarray. We convert it to an array
#     979 # container that is consistent with the input's namespace.
#     980 return xp.asarray(array)
#
# File c:\Users\Dell\Desktop\Internship_AI\venv\Lib\site-packages\pandas\core\generic.py:2039, in NDFrame.__array__(self, dtype, copy)
#    2035             )
#    2036         values = self._values
#    2037         if copy is None:
#    2038             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2039             arr = np.asarray(values, dtype=dtype)
#    2040         else:
#    2041             arr = np.array(values, dtype=dtype, copy=copy)
#    2042
#
# ValueError: could not convert string to float: 'Super Area'
